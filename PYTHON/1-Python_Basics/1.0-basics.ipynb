# %%
## Python is case sensative

name="Anmol"
Name="Agarwal"

print(name)
print(Name)
# Out:
# Anmol
# Agarwal

# %%
## Python uses indentation to define blocks of code

age=29
if age>30:
    print(age)

print(age)
# Out:
# 29

# %%
## Line continuation

total=1+2+3+4+5+\
6+7

print(total)
# Out:
# 28

# %%
## Multiple statment in a single line

x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
## variable assingment
age=32
name="Anmol"

type(age)
type(name)
# Out:
# str
